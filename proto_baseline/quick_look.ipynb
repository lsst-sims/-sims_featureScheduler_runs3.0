# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import pandas as pd
import rubin_sim.maf as maf
from rubin_sim.maf import radar

# %%
def norm_df(
    df,
    runs,
    cols,
    norm_run="baseline",
    invert_cols=None,
    reverse_cols=None,
    run_label="run_name",
    mag_cols=[],
):
    """
    Normalize values in a dataframe to a given run
    Parameters
    ----------
    df : pandas.DataFrame
        The input data frame
    runs : list of str
        A list of run numes
    cols : list of str
        A list of columns in df to use
    norm_run : str
        The row to use to normalize things to
    invert_cols : list of str
        A list of column names that should be inverted (e.g., columns that
        are uncertainties and are better with a smaller value)
    reverse_cols : list of str
        Columns to reverse (e.g., magnitudes)
    run_label : str (run_name)
        The column that has run names
    mag_cols : list of str
        Columns that are in magnitudes
    """
    indices = [np.max(np.where(df.index == name)[0]) for name in runs]
    out_df = df[cols].iloc[indices].copy()
    if reverse_cols is not None:
        for colname in reverse_cols:
            out_df[colname] = -out_df[colname]
    if invert_cols is not None:
        for colname in invert_cols:
            out_df[colname] = 1.0 / out_df[colname]
    if norm_run is not None:
        indx = np.max(np.where(out_df.index == norm_run)[0])
        for col in out_df.columns:
            # maybe just check that it's not a
            if col != "run_name":
                if (col in mag_cols) | (mag_cols == "all"):
                    out_df[col] = 1.0 + (out_df[col] - out_df[col].iloc[indx])
                else:
                    out_df[col] = (
                        1.0
                        + (out_df[col] - out_df[col].iloc[indx])
                        / out_df[col].iloc[indx]
                    )
    return out_df

# %%
data_loaded = pd.read_hdf('summary.h5')

# %%
[col for col in data_loaded.columns if 'DiscoveryNChances Vatira ' in col]
# Out:
# ['DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 16.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 16.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 16.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 16.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 16.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 17.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 17.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 17.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 17.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 17.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 18.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 18.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 18.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 18.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 18.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 19.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 19.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 19.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 19.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 19.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 20.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 20.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 20.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 20.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 20.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 21.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 21.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 21.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 21.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 21.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 22.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 22.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 22.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 22.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 22.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 23.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 23.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 23.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 23.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 23.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 24.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 24.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 24.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 24.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 24.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 25.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 25.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 25.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 25.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 25.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 26.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 26.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 26.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 26.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 26.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 27.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 27.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 27.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 27.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 27.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 28.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 16.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 16.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 16.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 16.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 16.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 17.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 17.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 17.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 17.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 17.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 18.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 18.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 18.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 18.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 18.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 19.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 19.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 19.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 19.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 19.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 20.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 20.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 20.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 20.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 20.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 21.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 21.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 21.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 21.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 21.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 22.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 22.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 22.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 22.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 22.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 23.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 23.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 23.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 23.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 23.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 24.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 24.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 24.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 24.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 24.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 25.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 25.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 25.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 25.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 25.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 26.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 26.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 26.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 26.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 26.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 27.000000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 27.200000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 27.400000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 27.600000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 27.800000',
#  'DiscoveryNChances Vatira 1 quad in 1 night detection loss DifferentialCompleteness H = 28.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 16.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 16.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 16.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 16.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 16.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 17.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 17.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 17.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 17.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 17.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 18.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 18.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 18.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 18.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 18.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 19.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 19.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 19.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 19.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 19.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 20.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 20.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 20.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 20.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 20.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 21.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 21.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 21.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 21.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 21.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 22.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 22.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 22.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 22.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 22.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 23.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 23.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 23.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 23.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 23.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 24.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 24.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 24.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 24.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 24.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 25.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 25.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 25.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 25.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 25.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 26.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 26.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 26.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 26.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 26.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 27.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 27.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 27.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 27.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 27.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss CumulativeCompleteness H <= 28.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 16.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 16.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 16.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 16.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 16.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 17.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 17.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 17.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 17.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 17.800000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 18.000000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 18.200000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 18.400000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H = 18.600000',
#  'DiscoveryNChances Vatira 3 pairs in 15 nights SNR=0 detection loss DifferentialCompleteness H =
400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 18.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 18.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 19.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 19.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 19.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 19.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 19.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 20.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 20.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 20.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 20.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 20.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 21.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 21.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 21.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 21.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 21.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 22.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 22.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 22.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 22.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 22.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 23.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 23.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 23.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 23.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 23.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 24.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 24.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 24.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 24.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 24.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 25.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 25.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 25.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 25.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 25.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 26.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 26.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 26.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 26.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 26.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 27.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 27.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 27.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 27.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 27.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights detection loss DifferentialCompleteness H = 28.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 16.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 16.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 16.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 16.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 16.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 17.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 17.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 17.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 17.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 17.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 18.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 18.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 18.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 18.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 18.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 19.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 19.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 19.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 19.600000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 19.800000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 20.000000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 20.200000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 20.400000',
#  'DiscoveryNChances Vatira 3 pairs in 30 nights trailing loss CumulativeCompleteness H <= 20.600000',
#  ...]

# %%
name_dict = {'parallax  best18k': 'parallax best 18k',
            'properMotion  best18k': 'proper motion best 18k',
            'MicrolensingMetric_detect tE 5_10 days Fraction detected of total (mean)': '5-10d microlensing\ndetection',
            'MicrolensingMetric_detect tE 60_90 days Fraction detected of total (mean)': '60-90d microlensing\ndetection',
            'fO  fONv MedianNvis': 'fO N vis',
            'SNNSNMetric_reducen_sn DDF excluded Total detected': 'SNe, N',
             'SNNSNMetric_reducezlim DDF excluded Median': 'SNe, zlim',
            'Exgalm5WithCuts i band non-DD year 10 3x2ptFoM': '3x2 i-band',
            'WeakLensingNvisits gri band non-DD Median': 'WL Nvis i-band',
            'PrestoKNe_score_s  Sum': 'KNe Presto S',
            'XRBPopMetric_early_detect  Total detected': 'XRB\nearly detect',
            'Brown Dwarf, L7  VolumeSum': 'Brown Dwarf Vol',
            'DiscoveryNChances NEO 3 pairs in 15 nights SNR=3 detection loss CumulativeCompleteness H <= 16.000000': 'NEO bright',
            'DiscoveryNChances NEO 3 pairs in 15 nights SNR=3 detection loss CumulativeCompleteness H <= 22.000000': 'NEO faint',
            'DiscoveryNChances TNO 3 pairs in 15 nights SNR=3 detection loss CumulativeCompleteness H <= 6.000000': 'TNO',
            'DiscoveryNChances Vatira 1 quad in 1 night detection loss CumulativeCompleteness H <= 16.000000': 'Vatira'}
invert_cols = ['parallax best 18k', 'proper motion best 18k']
mag_cols = ['5-10d microlensing\ndetection', '60-90d microlensing\ndetection', 'NEO bright', 'NEO faint', 'TNO']

data = pd.DataFrame()
for key in name_dict:
    data[name_dict[key]] = data_loaded[key]
    

mag_dict = {'CoaddM5 g Median': 'g',
 'CoaddM5 i Median': 'i',
 'CoaddM5 r Median': 'r',
 'CoaddM5 u Median': 'u',
 'CoaddM5 y Median': 'y',
 'CoaddM5 z Median': 'z'}

mag_data = pd.DataFrame()
for key in mag_dict:
    mag_data[mag_dict[key]] = data_loaded[key]
    
    
    
ddf_dict = {'SNNSNMetric DD:COSMOS_reducen_sn DD:COSMOS all bands, only DDF observations Sum' : 'N SN COSMOS',
           'SNNSNMetric DD:ECDFS_reducen_sn DD:ECDFS all bands, only DDF observations Sum' : 'N SN ECDFS',
           'SNNSNMetric DD:EDFS_reducen_sn DD:EDFS all bands, only DDF observations Sum' : 'N SN EDFS',
           'SNNSNMetric DD:ELAISS1_reducen_sn DD:ELAISS1 all bands, only DDF observations Sum' : 'N SN ELAISS1',
           'SNNSNMetric DD:XMM_LSS_reducen_sn DD:XMM_LSS all bands, only DDF observations Sum' : 'N SN XMM_LSS',
           'SNNSNMetric DD:COSMOS_reducezlim DD:COSMOS all bands, only DDF observations Median': 'zlim COSMOS',
            'SNNSNMetric DD:ECDFS_reducezlim DD:ECDFS all bands, only DDF observations Median': 'zlim ECDFS',
            'SNNSNMetric DD:EDFS_reducezlim DD:EDFS all bands, only DDF observations Median': 'zlim EDFS',
            'SNNSNMetric DD:ELAISS1_reducezlim DD:ELAISS1 all bands, only DDF observations Median': 'zlim ELAISS1',
            'SNNSNMetric DD:XMM_LSS_reducezlim DD:XMM_LSS all bands, only DDF observations Median': 'zlim XMM_LSS',
            
           }

ddf_data = pd.DataFrame()
for key in ddf_dict:
    ddf_data[ddf_dict[key]] = data_loaded[key]

# %%
data
# Out:
#                               parallax best 18k  proper motion best 18k  \
# baseline_v2.2_10yrs                    0.792958                0.186345
# draft2_rw0.5_v2.99_10yrs               0.787212                0.183319
# draft2_rw0.9_uz_v2.99_10yrs            0.792666                0.185683
# draft2_rw0.9_v2.99_10yrs               0.793345                0.185786
# proto_baseline_v3.0_10yrs              0.850979                0.200981
# proto_update_test_v3.0_10yrs           0.850979                0.200981
#
#                               5-10d microlensing\ndetection  \
# baseline_v2.2_10yrs                                  0.1656
# draft2_rw0.5_v2.99_10yrs                             0.1717
# draft2_rw0.9_uz_v2.99_10yrs                          0.1618
# draft2_rw0.9_v2.99_10yrs                             0.1657
# proto_baseline_v3.0_10yrs                            0.1331
# proto_update_test_v3.0_10yrs                         0.1331
#
#                               60-90d microlensing\ndetection  fO N vis  \
# baseline_v2.2_10yrs                                   0.4462     830.0
# draft2_rw0.5_v2.99_10yrs                              0.4732     789.0
# draft2_rw0.9_uz_v2.99_10yrs                           0.4559     795.0
# draft2_rw0.9_v2.99_10yrs                              0.4528     791.0
# proto_baseline_v3.0_10yrs                             0.3884     799.0
# proto_update_test_v3.0_10yrs                          0.3884     799.0
#
#                                      SNe, N  SNe, zlim  3x2 i-band  \
# baseline_v2.2_10yrs           112802.099640   0.289980   39.794283
# draft2_rw0.5_v2.99_10yrs      108633.666645   0.282821   38.967188
# draft2_rw0.9_uz_v2.99_10yrs   109475.798536   0.293926   38.643260
# draft2_rw0.9_v2.99_10yrs      109885.541234   0.297404   38.730595
# proto_baseline_v3.0_10yrs      84020.824949   0.270674   28.493745
# proto_update_test_v3.0_10yrs   84020.824949   0.270674   28.493745
#
#                               WL Nvis i-band  KNe Presto S  XRB\nearly detect  \
# baseline_v2.2_10yrs                    440.0         189.0             1921.0
# draft2_rw0.5_v2.99_10yrs               418.0         178.0             1989.0
# draft2_rw0.9_uz_v2.99_10yrs            423.0         200.0             1950.0
# draft2_rw0.9_v2.99_10yrs               421.0         163.0             1946.0
# proto_baseline_v3.0_10yrs              424.0         171.0             1759.0
# proto_update_test_v3.0_10yrs           424.0         171.0             1759.0
#
#                               Brown Dwarf Vol  NEO bright  NEO faint  \
# baseline_v2.2_10yrs             172453.127988      0.9304   0.657476
# draft2_rw0.5_v2.99_10yrs        170268.203068      0.9328   0.644530
# draft2_rw0.9_uz_v2.99_10yrs     168032.537231      0.9326   0.642155
# draft2_rw0.9_v2.99_10yrs        166437.978765         NaN        NaN
# proto_baseline_v3.0_10yrs       136741.283832      0.9324   0.609581
# proto_update_test_v3.0_10yrs    136741.283832         NaN        NaN
#
#                                    TNO  Vatira
# baseline_v2.2_10yrs           0.723913  0.0008
# draft2_rw0.5_v2.99_10yrs      0.720868  0.0337
# draft2_rw0.9_uz_v2.99_10yrs   0.722293  0.0376
# draft2_rw0.9_v2.99_10yrs      0.721724  0.0383
# proto_baseline_v3.0_10yrs     0.714225  0.0496
# proto_update_test_v3.0_10yrs       NaN     NaN

# %%
mag_data
# Out:
#                                       g          i          r          u  \
# baseline_v2.2_10yrs           26.753646  26.290929  26.835430  25.724699
# draft2_rw0.5_v2.99_10yrs      26.711248  26.278320  26.816224  25.691173
# draft2_rw0.9_uz_v2.99_10yrs   26.688123  26.264600  26.818287  25.668262
# draft2_rw0.9_v2.99_10yrs      26.691067  26.266481  26.796821  25.671016
# proto_baseline_v3.0_10yrs     26.590534  26.043099  26.660191  25.624956
# proto_update_test_v3.0_10yrs  26.590534  26.043099  26.660191  25.624956
#
#                                       y          z
# baseline_v2.2_10yrs           24.782743  25.581317
# draft2_rw0.5_v2.99_10yrs      24.749383  25.557561
# draft2_rw0.9_uz_v2.99_10yrs   24.756955  25.524781
# draft2_rw0.9_v2.99_10yrs      24.742600  25.536234
# proto_baseline_v3.0_10yrs     24.529065  25.286722
# proto_update_test_v3.0_10yrs  24.529065  25.286722

# %%
runs = [run for run in data.index ]
ndata = norm_df(data, runs, cols=data.columns.values.tolist(),
                invert_cols=invert_cols, mag_cols = mag_cols, norm_run='baseline_v2.2_10yrs')
fig, ax = radar(ndata, legend=True, rgrids=[0.6, 1.0, 1.3], bbox_to_anchor=(1.65, 0))

# %%
ndata = norm_df(mag_data, runs, cols=mag_data.columns.values.tolist(),
                mag_cols='all', norm_run='baseline_v2.2_10yrs')
fig, ax = radar(ndata, legend=True, rgrids=[0.8, 1.0, 1.2], bbox_to_anchor=(1.65, 0))

# %%
ndata = norm_df(ddf_data, runs, cols=ddf_data.columns.values.tolist(),
                norm_run='baseline_v2.2_10yrs')
fig, ax = radar(ndata, legend=True, rgrids=[0.8, 1.0, 1.2], bbox_to_anchor=(1.65, 0))

# %%
ddf_data
# Out:
#                            N SN COSMOS  N SN ECDFS     N SN EDFS  \
# baseline_v2.2_10yrs          13.647867    6.881372 -1.637500e+30
# proto_baseline_v3.0_10yrs   354.659752   61.204367  4.438273e+01
#
#                            N SN ELAISS1  N SN XMM_LSS  zlim COSMOS  \
# baseline_v2.2_10yrs            3.753806 -1.637500e+30     0.514987
# proto_baseline_v3.0_10yrs     35.048921  1.384527e+01     0.577762
#
#                            zlim ECDFS     zlim EDFS  zlim ELAISS1  \
# baseline_v2.2_10yrs          0.577431 -1.637500e+30      0.600156
# proto_baseline_v3.0_10yrs    0.530651  4.747630e-01      0.530788
#
#                            zlim XMM_LSS
# baseline_v2.2_10yrs       -1.637500e+30
# proto_baseline_v3.0_10yrs  5.349953e-01

# %%
data_loaded['DD:ELAISS1 NVisits all bands Median']
# Out:
# baseline_v2.2_10yrs          9991.0
# proto_baseline_v3.0_10yrs    9874.0
# Name: DD:ELAISS1 NVisits all bands Median, dtype: float64

# %%
data_loaded['DD:COSMOS NVisits all bands Median']
# Out:
# baseline_v2.2_10yrs           9853.0
# proto_baseline_v3.0_10yrs    19156.5
# Name: DD:COSMOS NVisits all bands Median, dtype: float64
